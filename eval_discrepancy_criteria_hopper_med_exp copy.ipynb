# %%
import rollout_doc_file_processor
import plotter
import numpy as np
from scipy.stats import spearmanr
import matplotlib.pyplot as plt
import seaborn as sns 
import os
import re

# %%
dir_path = "log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs"
env_name = "Hopper-v2"

# %%
doc_paths = [os.path.join(dir_path, f) for f in os.listdir(dir_path) if f.endswith('.json')]

# %%
docs = rollout_doc_file_processor.load_rollout_docs(doc_paths, add_model_error_if_not_contained=True, env=env_name, cast_to_nparray=False, verbose=True)
# Out:
# Processing rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_200_timesteps_199000_rollout_doc.json
# Rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_200_timesteps_199000_rollout_doc.json already contains next_obss_real and model_error_l2
# Processing rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_210_timesteps_209000_rollout_doc.json
# Rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_210_timesteps_209000_rollout_doc.json already contains next_obss_real and model_error_l2
# Processing rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_250_timesteps_249000_rollout_doc.json
# Rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_250_timesteps_249000_rollout_doc.json already contains next_obss_real and model_error_l2
# Processing rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_90_timesteps_89000_rollout_doc.json
# Rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_90_timesteps_89000_rollout_doc.json already contains next_obss_real and model_error_l2
# Processing rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_10_timesteps_9000_rollout_doc.json
# Rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_10_timesteps_9000_rollout_doc.json already contains next_obss_real and model_error_l2
# Processing rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_110_timesteps_109000_rollout_doc.json
# Rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_110_timesteps_109000_rollout_doc.json already contains next_obss_real and model_error_l2
# Processing rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_70_timesteps_69000_rollout_doc.json
# Rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_70_timesteps_69000_rollout_doc.json already contains next_obss_real and model_error_l2
# Processing rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_240_timesteps_239000_rollout_doc.json
# Rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_240_timesteps_239000_rollout_doc.json already contains next_obss_real and model_error_l2
# Processing rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_120_timesteps_119000_rollout_doc.json
# Rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_120_timesteps_119000_rollout_doc.json already contains next_obss_real and model_error_l2
# Processing rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_30_timesteps_29000_rollout_doc.json
# Rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_30_timesteps_29000_rollout_doc.json already contains next_obss_real and model_error_l2
# Processing rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_170_timesteps_169000_rollout_doc.json
# Rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_170_timesteps_169000_rollout_doc.json already contains next_obss_real and model_error_l2
# Processing rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_230_timesteps_229000_rollout_doc.json
# Rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_230_timesteps_229000_rollout_doc.json already contains next_obss_real and model_error_l2
# Processing rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_270_timesteps_269000_rollout_doc.json
# Rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_270_timesteps_269000_rollout_doc.json already contains next_obss_real and model_error_l2
# Processing rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_20_timesteps_19000_rollout_doc.json
# Rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_20_timesteps_19000_rollout_doc.json already contains next_obss_real and model_error_l2
# Processing rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_150_timesteps_149000_rollout_doc.json
# Rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_150_timesteps_149000_rollout_doc.json already contains next_obss_real and model_error_l2
# Processing rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_40_timesteps_39000_rollout_doc.json
# Rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_40_timesteps_39000_rollout_doc.json already contains next_obss_real and model_error_l2
# Processing rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_60_timesteps_59000_rollout_doc.json
# Rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_60_timesteps_59000_rollout_doc.json already contains next_obss_real and model_error_l2
# Processing rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_260_timesteps_259000_rollout_doc.json
# Rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_260_timesteps_259000_rollout_doc.json already contains next_obss_real and model_error_l2
# Processing rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_220_timesteps_219000_rollout_doc.json
# Rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_220_timesteps_219000_rollout_doc.json already contains next_obss_real and model_error_l2
# Processing rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_140_timesteps_139000_rollout_doc.json
# Rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_140_timesteps_139000_rollout_doc.json already contains next_obss_real and model_error_l2
# Processing rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_130_timesteps_129000_rollout_doc.json
# Rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_130_timesteps_129000_rollout_doc.json already contains next_obss_real and model_error_l2
# Processing rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_160_timesteps_159000_rollout_doc.json
# Rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_160_timesteps_159000_rollout_doc.json already contains next_obss_real and model_error_l2
# Processing rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_50_timesteps_49000_rollout_doc.json
# Rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_50_timesteps_49000_rollout_doc.json already contains next_obss_real and model_error_l2
# Processing rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_180_timesteps_179000_rollout_doc.json
# Rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_180_timesteps_179000_rollout_doc.json already contains next_obss_real and model_error_l2
# Processing rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_190_timesteps_189000_rollout_doc.json
# Rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_190_timesteps_189000_rollout_doc.json already contains next_obss_real and model_error_l2
# Processing rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_280_timesteps_279000_rollout_doc.json
# Rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_280_timesteps_279000_rollout_doc.json already contains next_obss_real and model_error_l2
# Processing rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_100_timesteps_99000_rollout_doc.json
# Rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_100_timesteps_99000_rollout_doc.json already contains next_obss_real and model_error_l2
# Processing rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_80_timesteps_79000_rollout_doc.json
# Rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_80_timesteps_79000_rollout_doc.json already contains next_obss_real and model_error_l2
# Loading rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_200_timesteps_199000_rollout_doc.json
# Loading rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_210_timesteps_209000_rollout_doc.json
# Loading rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_250_timesteps_249000_rollout_doc.json
# Loading rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_90_timesteps_89000_rollout_doc.json
# Loading rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_10_timesteps_9000_rollout_doc.json
# Loading rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_110_timesteps_109000_rollout_doc.json
# Loading rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_70_timesteps_69000_rollout_doc.json
# Loading rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_240_timesteps_239000_rollout_doc.json
# Loading rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_120_timesteps_119000_rollout_doc.json
# Loading rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_30_timesteps_29000_rollout_doc.json
# Loading rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_170_timesteps_169000_rollout_doc.json
# Loading rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_230_timesteps_229000_rollout_doc.json
# Loading rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_270_timesteps_269000_rollout_doc.json
# Loading rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_20_timesteps_19000_rollout_doc.json
# Loading rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_150_timesteps_149000_rollout_doc.json
# Loading rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_40_timesteps_39000_rollout_doc.json
# Loading rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_60_timesteps_59000_rollout_doc.json
# Loading rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_260_timesteps_259000_rollout_doc.json
# Loading rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_220_timesteps_219000_rollout_doc.json
# Loading rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_140_timesteps_139000_rollout_doc.json
# Loading rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_130_timesteps_129000_rollout_doc.json
# Loading rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_160_timesteps_159000_rollout_doc.json
# Loading rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_50_timesteps_49000_rollout_doc.json
# Loading rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_180_timesteps_179000_rollout_doc.json
# Loading rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_190_timesteps_189000_rollout_doc.json
# Loading rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_280_timesteps_279000_rollout_doc.json
# Loading rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_100_timesteps_99000_rollout_doc.json
# Loading rollout document log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_80_timesteps_79000_rollout_doc.json

# %%
# add epoch info to docs
for doc, path in zip(docs, doc_paths):
    match = re.search(r'epoch_(\d+)', path)
    if match:
        epoch = int(match.group(1))
        n = len(doc['obss'])
        doc["epoch"] = [epoch] * n

# %%
# consolidate all dicts in docs
consolidated_doc = {}
for doc in docs:
    for key, value in doc.items():
        if key not in consolidated_doc:
            consolidated_doc[key] = []
        consolidated_doc[key] += value
docs = None

# %%
consolidated_doc.keys()
# Out:
# dict_keys(['obss', 'next_obss_predicted', 'actions', 'step_nr', 'aleatoric', 'pairwise-diff', 'pairwise-diff_with_std', 'ensemble_std', 'dimensionwise_diff_with_std', 'next_obss_real', 'model_error_l2', 'rewards_real', 'epoch'])

# %%
for k,v in consolidated_doc.items():
    consolidated_doc[k] = np.array(v)

# %%
    # doc = rollout_doc_file_processor.load_rollout_docs("log/hopper-medium-expert-v2/combo/seed_1_timestamp_25-0825-124532/rollout_docs/epoch_220_timesteps_219000_rollout_doc.json")
    # doc = doc[0]
    # doc.keys()

doc = consolidated_doc

# %%
uncertainty_measures = list(doc.keys())
uncertainty_measures.remove('obss')
uncertainty_measures.remove('actions')
uncertainty_measures.remove('next_obss_predicted')
uncertainty_measures.remove('next_obss_real')
uncertainty_measures.remove('model_error_l2')
uncertainty_measures.remove('rewards_real')
uncertainty_measures.remove('epoch')
uncertainty_measures.remove('step_nr')

uncertainty_measures
# Out:
# ['aleatoric',
#  'pairwise-diff',
#  'pairwise-diff_with_std',
#  'ensemble_std',
#  'dimensionwise_diff_with_std']

# %%
plotter.plot_correlation_bars(doc, uncertainty_measures, error_key='model_error_l2', title='Correlation of Uncertainty Measures with Model Error', print_corr_values=True, fig_size=(10, 6))
# Out:
# Uncertainty Measure: aleatoric                      pearson corr: 0.620572 spearman rank corr: 0.705878
# Uncertainty Measure: pairwise-diff                  pearson corr: 0.555896 spearman rank corr: 0.648686
# Uncertainty Measure: pairwise-diff_with_std         pearson corr: 0.677675 spearman rank corr: 0.700169
# Uncertainty Measure: ensemble_std                   pearson corr: 0.543818 spearman rank corr: 0.688319
# Uncertainty Measure: dimensionwise_diff_with_std    pearson corr: 0.668495 spearman rank corr: 0.722645

# %%
# Prepare data for correlation matrix
uncertainty_data = np.stack([doc[k] for k in uncertainty_measures], axis=1)
corr_matrix = np.corrcoef(uncertainty_data, rowvar=False)

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, xticklabels=uncertainty_measures, yticklabels=uncertainty_measures, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix of Uncertainty Measures")
plt.tight_layout()
plt.show()

# %%
for u in uncertainty_measures:
    plotter.plot_scatter_correlation(x=doc[u], y=doc["model_error_l2"], title=f"{u} vs Model Error L2", xlabel=u, ylabel="Model Error L2", bins=10000, mark_percentile=70, fig_size=(6, 6), points_s=0.5, points_alpha=0.05)

# %%
doc.keys()
# Out:
# dict_keys(['obss', 'next_obss_predicted', 'actions', 'step_nr', 'aleatoric', 'pairwise-diff', 'pairwise-diff_with_std', 'ensemble_std', 'dimensionwise_diff_with_std', 'next_obss_real', 'model_error_l2', 'rewards_real', 'epoch'])

# %%
plotter.plot_scatter_correlation(x=doc[u], y=doc["model_error_l2"], title=f"{u} vs Model Error L2", xlabel=u, ylabel="Model Error L2", bins=10000, mark_percentile=70, fig_size=(6, 6), points_s=0.5, points_alpha=0.05)

# %% [markdown]
# #### Fit OLS Model

# %%
unc_data = np.stack([doc[k] for k in uncertainty_measures]).T
target = doc["model_error_l2"]
unc_data.shape, target.shape
# Out:
# ((9765792, 5), (9765792,))

# %%
# Fit linear regression model
reg_strength = 0.5
beta = np.linalg.inv(unc_data.T @ unc_data + reg_strength) @ unc_data.T @ target
y_hat = unc_data @ beta
beta, y_hat.shape
# Out:
# (array([-0.34928188, -0.06552102,  0.92008606, -7.12479997,  0.54578387]),
#  (9765792,))

# %%
plotter.plot_scatter_correlation(x= y_hat, y=doc["model_error_l2"], title=f"Combining Uncertainty Measures -OLS Error Prediction vs L2 Model Error", xlabel="OLS Error Prediction", ylabel="Model Error L2", bins=800, mark_percentile=70, fig_size=(6, 6), points_s=0.5, points_alpha=0.05)

# %%
plotter.plot_scatter_correlation(x= y_hat, y=doc["rewards_real"], title=f"OLS Error Prediction using all uncertainty measures vs Real Reward", xlabel="OLS Error Prediction", ylabel="Real Reward", bins=800, mark_percentile=70, fig_size=(6, 6), points_s=0.5, points_alpha=0.05)

# %% [markdown]
# => No correlation between discrepancy measures and real rewards. Thus, by filtering out data with high discrepancy measure we don't remove well performing transitions in particular

# %% [markdown]
# ## Logistic Regression on all Features as Filter Criterion - Target L2 Error Threshold: 0.1

# %%
# Logistic Regression to find criterion to filter model_error > 0.1

threshold = 0.1

targets_log_reg = (doc["model_error_l2"] > threshold).astype(int)
sample_weights = np.clip(np.abs(doc["model_error_l2"] - threshold)**0.5, 0, 2) # clipped sqrt abs distance

targets_log_reg.shape, sample_weights.shape
# Out:
# ((9765792,), (9765792,))

# %%
plt.figure(figsize=(8, 4))
plt.hist(sample_weights, bins=1000, color='skyblue', edgecolor='black')
mean_val = np.mean(sample_weights)
plt.axvline(mean_val, color='r', linestyle='--', linewidth=1, label=f"Mean: {mean_val:.3f}")
plt.xlabel("Sample Weights")
plt.ylabel("Count")
plt.title("Histogram of Sample Weights for Logistic Regression")
plt.legend()
plt.show()

# %%
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression(max_iter=1000)
log_reg.fit(unc_data, targets_log_reg, sample_weight=sample_weights)
log_reg.coef_
# Out:
# array([[ -3.14607254,   3.02405944, -11.75425155,   2.41841186,
#          16.34442029]])

# %%
y_hat_log_reg = log_reg.predict(unc_data)
y_hat_log_reg.shape
# Out:
# (9765792,)

# %%
x = y_hat
y = doc["model_error_l2"]

# Prepare colors by y_hat_log_reg
colors = np.where(y_hat_log_reg == 1, "red", "green")

plt.figure(figsize=(7, 7))
plt.scatter(x, y, c=colors, s=2, alpha=0.1, label=None)
plt.xscale("log")
plt.yscale("log")
plt.xlabel("OLS prediction (log scale)")
plt.ylabel("model_error_l2 (log scale)")
plt.title("Accepted and Filtered Out Data - Displayed on OLS Prediction vs Model Error Plot")

# Add legend for colors
import matplotlib.patches as mpatches
plt.legend(handles=[
    mpatches.Patch(color='green', label='Accepted by Log-Reg'),
    mpatches.Patch(color='red', label='Filtered out by Log-Reg')
], loc='upper left')

plt.tight_layout()
plt.show()

# %%
y_hat_log_reg.shape
# Out:
# (9765792,)

# %%
plotter.plot_filtering_analysis(doc, filter_indicator=y_hat_log_reg, bins=800, fig_size=(22, 9), filter_criterion="Logistic Regression Prediction - trained to filter out errors above 0.1")

# %% [markdown]
# ### Heuristic Filter Criterion - Filter out iff dimensionwise_diff_with_std > 0.15 OR aleatoric > 0.15

# %%
filter_indicator = (doc["dimensionwise_diff_with_std"] > 0.15) | (doc["aleatoric"] > 0.15)
filter_indicator.shape
# Out:
# (9765792,)

# %%
sum(y_hat_log_reg)
# Out:
# 1213825

# %%
plotter.plot_filtering_analysis(doc, filter_indicator=filter_indicator, bins=600, fig_size=(22, 9), filter_criterion="dimensionwise_diff_with_std > 0.15 OR aleatoric > 0.15")

# %%
plotter.plot_model_error_all_vs_accepted_per_step(doc, filter_indicator, epoch_vals=[225,250,350], title='Model Error Analysis With Performant Rollout Policy', statistics=["mean", "median", "P90"], curves_logscale=False)

# %%
plotter.plot_model_error_all_vs_accepted_per_step(doc, filter_indicator, epoch_vals=[25,50], title='Model Error Analysis With Underfitted Rollout Policy', statistics=["mean", "median", "P90"], curves_logscale=False)

# %% [markdown]
# => Model error doesn't change much with rollout policy actor quality (with same dynamics model)
